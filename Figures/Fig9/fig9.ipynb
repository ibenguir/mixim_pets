# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib
import matplotlib.pyplot as plt

# %%
#Partial Routing L=3 W =50 B0 ETE1
ent_PartialD_B0 = [2.623908127813623, 5.69779024250381, 6.8131527402621295, 7.265026260809952]
ent_LinkD_B0 = [2.623908127813623,5.716833487504887, 6.7912814531641175, 7.272425539965865]
ent_PartialD_B10 = [2.516215050711296,4.836119230057101, 5.590160673591185, 6.112656313468889]
ent_LinkD_B10 = [2.516215050711296, 4.846342650732345, 5.527136745897416, 5.949233675750725]
dummies_rate = ['$0$','$1.5x10²$', '$1.5x10³$', '$1.5x10⁴$']
# 3*10⁴ partial dummies ,  7.261408611156299
#3*10⁴ Link dummies 7.2570541603325776

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(1, 1, 1)
ax.plot(dummies_rate, ent_PartialD_B0, ':', linewidth=1.5, color='Black', label = "Partial-route b = 0");
ax.plot(dummies_rate, ent_LinkD_B0, 'x', color='red', label = "Link-based b = 0");
ax.plot(dummies_rate, ent_PartialD_B10, ':', linewidth=1.5, color='blue', label = "Partial-route b = 0.1");
ax.plot(dummies_rate, ent_LinkD_B10, 'o', color='green', label = "Link-based b = 0.1");

ax.set_xlabel('Dummy Budget', fontsize=14)
ax.set_ylabel('Mean Entropy (bits)', fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
ax.set_ylim(0, 8)
plt.legend(fontsize=14)

# %%
#B=10%
ent_PartialD_B10 = [2.516215050711296,4.836119230057101, 5.590160673591185, 6.112656313468889]
ent_LinkD_B10 = [2.516215050711296, 4.846342650732345, 5.527136745897416, 5.949233675750725]
# 3*10⁴ partial dummies , 6.488607366719523
#3*10⁴ Link dummies 5.9429395145107256

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(1, 1, 1)
ax.plot(dummies_rate, ent_PartialD_B10, ':', linewidth=1.5, color='Black', label = "Partial-route");
ax.plot(dummies_rate, ent_LinkD_B10, 'x',color='red', label = "Link-based");
ax.set_xlabel('Dummy Budget', fontsize=14)
ax.set_ylabel('Mean Entropy (bits)', fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
ax.set_ylim(0, 8)
plt.legend(fontsize=14)

# %%
ent_LinkDummies_B20 = [2.134542144239899, 4.356814460224538, 4.513352028858669, 4.870666107478787]
ent_partialDummies_B20 = [2.134542144239899, 4.24156104556791, 5.337934421466246, 5.639961717486371]
ent_LinkDummies_B30 = [1.8960636458129871, 3.440378804505192, 3.4520711038211753, 3.7880458736053626]
ent_PartialDummies_B30 = [1.8960636458129871, 3.712664031762281, 4.029403720505889, 4.430552220744752]
# 3*10⁴ link dummies , 4.818161775629208
#3*10⁴ partial dummies 5.610279167511102
#last two   4.8139782301058665, 5.490089620026094

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(1, 1, 1)
ax.plot(dummies_rate, ent_partialDummies_B20,':', linewidth=1.5,  color='black', label = "Partial-route b = 0.2");
ax.plot(dummies_rate, ent_LinkDummies_B20, 'x', color='red', label = "Link-based b = 0.2");
ax.plot(dummies_rate, ent_PartialDummies_B30, ':', color='green', label = "Partial-route b = 0.3");
ax.plot(dummies_rate, ent_LinkDummies_B30, 'o', linewidth=1.5, color='blue', label = "Link-based b = 0.3");
ax.set_xlabel('Dummy Budget', fontsize=14)
ax.set_ylabel('Mean Entropy (bits)', fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
ax.set_ylim(0, 8)
plt.legend(bbox_to_anchor=(0.46, 1), prop={"size":14})

#plt.legend(fontsize=14)

# %%
ent_LinkDummies_B30 = [1.8960636458129871, 3.440378804505192, 3.4520711038211753, 3.7880458736053626]
ent_PartialDummies_B30 = [1.8960636458129871, 3.712664031762281, 4.029403720505889, 4.430552220744752]

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(1, 1, 1)
ax.plot(dummies_rate, ent_PartialDummies_B30,':', linewidth=1.5,  color='black', label = "Partial-route");
ax.plot(dummies_rate, ent_LinkDummies_B30, 'x', color='red', label = "Link-based");
ax.set_xlabel('Dummy Budget', fontsize=14)
ax.set_ylabel('Mean Entropy (bits)', fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
ax.set_ylim(0, 8)
plt.legend(fontsize=14)

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib
import matplotlib.pyplot as plt

# %%
#Partial Routing L=3 W =50 B0 ETE1
dummies_rate = ['$0$','$1.5x10²$', '$1.5x10³$', '$1.5x10⁴$']

partial_b0 = [2.623908127813623, 5.69779024250381, 6.8131527402621295, 7.265026260809952]
Link_b0 = [2.623908127813623,5.716833487504887, 6.7912814531641175, 7.272425539965865]
Partial_b10 = [2.516215050711296,4.836119230057101, 5.590160673591185, 6.112656313468889]
Link_b10 = [2.516215050711296, 4.846342650732345, 5.527136745897416, 5.949233675750725]

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(1, 1, 1)
ax.plot(dummies_rate, partial_b0, ':', linewidth=1.5, color='Black', label = "Partial-route b = 0");
ax.plot(dummies_rate, Link_b0, 'x', color='red', label = "Link-based b = 0");
ax.plot(dummies_rate, Partial_b10, ':', linewidth=1.5, color='blue', label = "Partial-route b = 0.1");
ax.plot(dummies_rate, Link_b10, 'o', color='green', label = "Link-based b = 0.1");

ax.set_xlabel('Dummy Budget', fontsize=14)
ax.set_ylabel('Mean Entropy (bits)', fontsize=14)
plt.yticks(fontsize=14)
plt.xticks(fontsize=14)
ax.set_ylim(0, 8)
plt.legend(fontsize=14)

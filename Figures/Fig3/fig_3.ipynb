# %%
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib
import matplotlib.pyplot as plt

# %%
L = ["2","3","4", "5"]
N= 100
alphaF_b10 = [0.00909090909090909, 0.0007646033620059595,5.355469272995048e-05, 3.34716829562191e-06 ]
alphaF_b20 = [0.03838383838383838,0.007263731939056611,0.0012355832679838551,  0.00020593054466397815]
alphaF_b30 = [0.08787878787878786, 0.025869080414534968, 0.006988887401258523, 0.0018928236711742044]

# %%
probWorstCaseB10 = [0.01, 0.001, 0.0001, 0.00001]
probWorstCaseB20 = [0.04, 0.008, 0.0016, 3.2e-04]
probWorstCaseB30 = [0.09, 0.027, 0.0081, 0.00243]

# %%
fig = plt.figure(figsize=(8,6), dpi= 100, facecolor='w', edgecolor='k')

df=pd.DataFrame({ 'y1_values': alphaF_b10, 'y2_values': alphaF_b20, 'y3_values': alphaF_b30})

# multiple line plots

plt.plot( L, 'y3_values', data=df, marker='', color='orange', linewidth=2, label="b = 0.3")
plt.plot( L, 'y2_values', data=df, marker='', color='red', linewidth=2, label="b = 0.2")
plt.plot( L, 'y1_values', data=df, marker='', markerfacecolor='blue', color='skyblue', label="b = 0.1")


plt.plot(L, probWorstCaseB10, '*', color='black');
plt.plot(L, probWorstCaseB20, '*', color='black');
plt.plot(L, probWorstCaseB30, '*', color='black');
# show legend
plt.ylabel(r'$\alpha_F$', fontsize = 14)
plt.xlabel('Layers', fontsize = 14)

plt.legend()

# show graph
plt.show()
